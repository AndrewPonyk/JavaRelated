# %% [markdown]
# # Lesson NN — <Topic>
#
# **Course:** <course code> · **Estimated time:** NN min · **Author:** <instructor>
#
# ## Learning objectives
#
# - TODO: objective 1 (verb: derive / implement / compare …)
# - TODO: objective 2
#
# ## Prerequisites
#
# - TODO: prior lessons / math background

# %% [markdown]
# ## Theory
#
# TODO: exposition with LaTeX, e.g.
#
# $$ \int_a^b f(x)\,dx \approx \frac{h}{2}\sum_{i=1}^{n}\left(f(x_{i-1}) + f(x_i)\right) $$

# %%
# Guided example — TODO: build the worked example with sciengine here.
# Keep imports at the top of the cell; the notebook must run top-to-bottom
# (CI executes it with nbmake).
from sciengine.numerical.integration import integrate_function  # noqa: F401

# %% [markdown]
# ## Exercises
#
# 1. TODO: exercise 1
# 2. TODO: exercise 2 (harder)
# 3. TODO: challenge exercise

# %%
# Solution scaffold — cells tagged 'solution' are stripped from the student
# copy by the publishing pipeline (Phase 3).
# TODO: reference solutions

# %% [markdown]
# ## Assessment rubric
#
# TODO: criteria and tolerances (remember: numerical answers are graded with
# `math.isclose`-style tolerance, never exact equality).

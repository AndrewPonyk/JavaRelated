# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Exploratory analysis for the Customer Churn Predictor. **Not** part of the
# production path. Strip outputs before committing (`nbstripout`).
#
# ## TODO
# - [ ] Load data via `churn_predictor.data.loader.load_customers`
# - [ ] Target balance (churn rate) and class imbalance check
# - [ ] Univariate distributions + missingness
# - [ ] Correlations / leakage candidates
# - [ ] Baseline model sanity check

# %%
from churn_predictor.data.loader import load_customers

# df = load_customers(source="csv", path="../data/raw/customers.csv")
# df['is_churned'].mean()  # churn rate
